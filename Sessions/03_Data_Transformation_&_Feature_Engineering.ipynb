# %% [markdown]
# # **DATA TRANSFORMATION & FEATURE ENGINEERING**

# %% [markdown]
# **Load the Dataset**

# %%
import pandas as pd
import numpy as np

# "../Datasets/energy_data_sustainability.csv"
# "C:\Users\ASUS\Desktop\CICLOS - PUCP\2025-2\DATA MINING\LAB3"
energy_data = pd.read_csv(f"C:/Users/ASUS/Desktop/CICLOS - PUCP/2025-2/DATA MINING/LAB3/energy_data_sustainability.csv")
energy_data
# Out:
#      household_id  daily_energy_kwh  monthly_income_usd    region  \
# 0               1              5.97              1361.0  suburban
# 1               2              3.94              2707.0  suburban
# 2               3              3.68              1239.0     rural
# 3               4              3.68              1327.0     urban
# 4               5             10.84              1993.0  suburban
# ..            ...               ...                 ...       ...
# 495           496              2.77              2690.0     rural
# 496           497              3.29              1363.0  suburban
# 497           498              5.23              2087.0  suburban
# 498           499              5.39              1105.0  suburban
# 499           500              3.83              1205.0     urban
#
#        device_type   timestamp  num_devices  household_size  \
# 0    solar_monitor  2024-03-31            5               5
# 1    hybrid_system  2023-02-23            4               4
# 2    hybrid_system  2023-02-21            6               6
# 3       grid_meter  2023-05-28            3               7
# 4    hybrid_system  2023-06-09            1              10
# ..             ...         ...          ...             ...
# 495  hybrid_system  2023-08-25            1               3
# 496  hybrid_system  2024-02-29            9               8
# 497  solar_monitor  2023-08-09            5               2
# 498  solar_monitor  2023-03-09            3               4
# 499  solar_monitor  2023-07-16            4               9
#
#      green_awareness_score energy_saving_level
# 0                     72.0              medium
# 1                     57.6                high
# 2                     87.2                 low
# 3                     11.2              medium
# 4                     15.0              medium
# ..                     ...                 ...
# 495                   51.3                high
# 496                   56.4              medium
# 497                   43.8              medium
# 498                   94.6                high
# 499                   50.2              medium
#
# [500 rows x 10 columns]

# %%
# Inspect the structure
energy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   household_id           500 non-null    int64
#  1   daily_energy_kwh       500 non-null    float64
#  2   monthly_income_usd     500 non-null    float64
#  3   region                 500 non-null    object
#  4   device_type            500 non-null    object
#  5   timestamp              500 non-null    object
#  6   num_devices            500 non-null    int64
#  7   household_size         500 non-null    int64
#  8   green_awareness_score  500 non-null    float64
#  9   energy_saving_level    500 non-null    object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 39.2+ KB

# %%
# From timestamp to date-time format
energy_data['timestamp'] = pd.to_datetime(energy_data['timestamp'])

# %%
# Visualize numerical summary
energy_data.describe()
# Out:
#        household_id  daily_energy_kwh  monthly_income_usd  \
# count    500.000000        500.000000          500.000000
# mean     250.500000          4.965000         2005.618000
# min        1.000000          0.080000          200.000000
# 25%      125.750000          2.785000         1453.500000
# 50%      250.500000          4.380000         2016.500000
# 75%      375.250000          6.442500         2481.500000
# max      500.000000         17.180000         4372.000000
# std      144.481833          3.001835          755.247444
#
#                         timestamp  num_devices  household_size  \
# count                         500   500.000000      500.000000
# mean   2023-08-06 14:29:45.600000     3.950000        3.974000
# min           2023-01-03 00:00:00     1.000000        1.000000
# 25%           2023-04-11 18:00:00     3.000000        3.000000
# 50%           2023-08-01 12:00:00     4.000000        4.000000
# 75%           2023-12-02 06:00:00     5.000000        5.000000
# max           2024-04-01 00:00:00    11.000000       10.000000
# std                           NaN     1.806107        1.724898
#
#        green_awareness_score
# count             500.000000
# mean               50.180000
# min                 3.600000
# 25%                32.000000
# 50%                50.850000
# 75%                68.050000
# max                99.500000
# std                22.863022

# %%
# Visualize the categorical variables summary
energy_data.describe(include="object")
# Out:
#           region device_type energy_saving_level
# count        500         500                 500
# unique         3           3                   3
# top     suburban  grid_meter              medium
# freq         212         177                 249

# %% [markdown]
# ## **DATA TRANSFORMATION**
#
# ### **1. Normalitation (Min - Max)**

# %%
# Before Normalitation
energy_data['monthly_income_usd'].describe()
# Out:
# count     500.000000
# mean     2005.618000
# std       755.247444
# min       200.000000
# 25%      1453.500000
# 50%      2016.500000
# 75%      2481.500000
# max      4372.000000
# Name: monthly_income_usd, dtype: float64

# %%
# Apply normalitation on "monthly_income_norm" variable
energy_data['monthly_income_norm'] = energy_data['monthly_income_usd'].transform(lambda x: (x - x.min())/(x.max() - x.min()))

# After normalitation
energy_data['monthly_income_norm'].describe()
# Out:
# count    500.000000
# mean       0.432794
# std        0.181028
# min        0.000000
# 25%        0.300455
# 50%        0.435403
# 75%        0.546860
# max        1.000000
# Name: monthly_income_norm, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['monthly_income_usd', 'monthly_income_norm']
titles = ["Monthly Income (USD)", "Normalized Monthly Income"]
colors = ['skyblue', 'green']

fig, axes = plt.subplots(2, 1, figsize=(8, 6))

sns.set_style("darkgrid")
for ax, col, title, color in zip(axes, cols, titles, colors):
    sns.histplot(data=energy_data, x=col, bins=15, color=color, ax=ax)
    ax.set_title(title)
    ax.set_xlabel(col)
    ax.set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **2. Standarization (Z-score)**

# %%
# Before standarization of "daily_energy_kwh" variable
energy_data['daily_energy_kwh'].describe()
# Out:
# count    500.000000
# mean       4.965000
# std        3.001835
# min        0.080000
# 25%        2.785000
# 50%        4.380000
# 75%        6.442500
# max       17.180000
# Name: daily_energy_kwh, dtype: float64

# %%
# Apply Z-score standardization
# Rescale the variable (mean = 0, std = 1)
from scipy.stats import zscore

energy_data['daily_energy_z'] = zscore(energy_data['daily_energy_kwh'])

# After standarization
energy_data['daily_energy_z'].describe().round(4)
# Out:
# count    500.0000
# mean       0.0000
# std        1.0010
# min       -1.6290
# 25%       -0.7269
# 50%       -0.1951
# 75%        0.4927
# max        4.0733
# Name: daily_energy_z, dtype: float64

# %%
# Create graphs and compare the before and after of "daily_energy_kwh" variable
cols1 = ['daily_energy_kwh', 'daily_energy_z']
titles1 = ["Original Daily Energy Usage (kWh)", "Z-score Standardized Energy Usage"]
colors1 = ["lightblue", "lightcoral"]

fig, axes = plt.subplots(2, 1, figsize = (8,6))

for ax, col, title, color in zip(axes, cols1, titles1, colors1):
    sns.histplot(data=energy_data, x=col, bins=15, color=color, ax=ax)
    ax.set_title(title)
    ax.set_xlabel(col)
    ax.set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **3. Distribution Shaping**

# %%
# Log transform daily_energy_kwh (add 1 to avoid log(0))
energy_data['log_energy_kwh'] = np.log1p(energy_data['daily_energy_kwh'])

# Square root transformation
energy_data['sqrt_energy_kwh'] = np.sqrt(energy_data['daily_energy_kwh'])

# Box-Cox transformation
from scipy.stats import boxcox
energy_data['boxcox_energy_kwh'], lambda_opt = boxcox(energy_data['daily_energy_kwh'])

print("Optimal lambda: ", lambda_opt)
# Out:
# Optimal lambda:  0.3218134461515229

# %%
# Plot all three transformation
cols2 = ["daily_energy_kwh", "log_energy_kwh", "sqrt_energy_kwh", "boxcox_energy_kwh"]
titles2 = ["Original", "Log(x+1)", "Square Root", f"Box-Cox λ = {lambda_opt:.2f}"]
colors2 = ["lightblue", "lightgreen", "lightcoral", "goldenrod"]

fig, axes = plt.subplots(2, 2, figsize = (9,5))
axes = axes.flatten()

for ax, col, title, color in zip(axes, cols2, titles2, colors2):
    sns.histplot(data=energy_data, x=col, bins=15, color=color, ax=ax)
    ax.set_title(title)
    ax.set_xlabel(col)
    ax.set_ylabel("Frequency")

plt.tight_layout(pad=1.5)
plt.show()

# %%
# Check all the transformation for "daily_energy_kwh"
energy_data.filter(like="energy").describe()
# Out:
#        daily_energy_kwh  daily_energy_z  log_energy_kwh  sqrt_energy_kwh  \
# count        500.000000    5.000000e+02      500.000000       500.000000
# mean           4.965000    4.263256e-17        1.663964         2.128723
# std            3.001835    1.001002e+00        0.501305         0.659097
# min            0.080000   -1.628968e+00        0.076961         0.282843
# 25%            2.785000   -7.269497e-01        1.331043         1.668830
# 50%            4.380000   -1.950760e-01        1.682687         2.092844
# 75%            6.442500    4.926918e-01        2.007207         2.538208
# max           17.180000    4.073253e+00        2.900322         4.144876
#
#        boxcox_energy_kwh
# count         500.000000
# mean            1.888730
# std             1.015569
# min            -1.728926
# 25%             1.213230
# 50%             1.891004
# 75%             2.551879
# max             4.652273

# %% [markdown]
# ### **4. Encode categorical variables**

# %%
# Display unique values for all character variables
for col in energy_data.select_dtypes(include='object').columns:
    print(f"\n{col}", energy_data[col].unique(), sep="\n")
# Out:
# region
# ['suburban' 'rural' 'urban']
#
# device_type
# ['solar_monitor' 'hybrid_system' 'grid_meter']
#
# energy_saving_level
# ['medium' 'high' 'low']

# %%
# Convert 'energy_saving_level' to a categorical variable
energy_data['energy_saving_level'] = pd.Categorical(energy_data['energy_saving_level'], 
                                                    categories=['low', 'medium', 'high'], ordered=True)

energy_data['energy_saving_encoded'] = energy_data['energy_saving_level'].cat.codes + 1

# Cross-check that encoding matches the factor levels
pd.crosstab(energy_data['energy_saving_level'], energy_data['energy_saving_encoded'])
# Out:
# energy_saving_encoded    1    2   3
# energy_saving_level
# low                    165    0   0
# medium                   0  249   0
# high                     0    0  86

# %%
# Create dummy variables for 'region'
dummies = pd.get_dummies(energy_data['region'], prefix='region')
energy_data = pd.concat([energy_data, dummies], axis=1)

# Check results
energy_data[['household_id']].join(energy_data.filter(like='region')).head()
# Out:
#    household_id    region  region_rural  region_suburban  region_urban
# 0             1  suburban         False             True         False
# 1             2  suburban         False             True         False
# 2             3     rural          True            False         False
# 3             4     urban         False            False          True
# 4             5  suburban         False             True         False

# %%
# Check proportion of original categories (baseline)
energy_data["region"].value_counts(normalize=True)
# Out:
# region
# suburban    0.424
# urban       0.374
# rural       0.202
# Name: proportion, dtype: float64

# %%
# Check if dummy variables are correctly encoded by comparing means
energy_data.filter(like="region_").mean()
# Out:
# region_rural       0.202
# region_suburban    0.424
# region_urban       0.374
# dtype: float64

# %% [markdown]
# ## **FEATURE ENGINEERING**
#
# ### **1. Creating New Features**

# %% [markdown]
# 1. **Ratios (e.g., income-per-person)**

# %%
# Example: Create a ratio feature – income per person in the household
energy_data['income_per_person'] = energy_data['monthly_income_usd']/energy_data['household_size']

# Select the variables to check the calculations
energy_data[['household_id', 'monthly_income_usd', 'household_size', 'income_per_person']]
# Out:
#      household_id  monthly_income_usd  household_size  income_per_person
# 0               1              1361.0               5         272.200000
# 1               2              2707.0               4         676.750000
# 2               3              1239.0               6         206.500000
# 3               4              1327.0               7         189.571429
# 4               5              1993.0              10         199.300000
# ..            ...                 ...             ...                ...
# 495           496              2690.0               3         896.666667
# 496           497              1363.0               8         170.375000
# 497           498              2087.0               2        1043.500000
# 498           499              1105.0               4         276.250000
# 499           500              1205.0               9         133.888889
#
# [500 rows x 4 columns]

# %%
# Summary statistics of the feature created
energy_data['income_per_person'].describe()
# Out:
# count     500.000000
# mean      637.896805
# std       448.051112
# min        23.555556
# 25%       335.475000
# 50%       526.857143
# 75%       794.000000
# max      3225.000000
# Name: income_per_person, dtype: float64

# %% [markdown]
# 2. **Time-Based Features**

# %%
# Extract month from the timestamp as a number and weekday as a labeled factor
energy_data = energy_data.assign(month = energy_data['timestamp'].dt.month, 
                                 weekday = energy_data['timestamp'].dt.day_name())

energy_data[['timestamp', 'month', 'weekday']]
# Out:
#      timestamp  month    weekday
# 0   2024-03-31      3     Sunday
# 1   2023-02-23      2   Thursday
# 2   2023-02-21      2    Tuesday
# 3   2023-05-28      5     Sunday
# 4   2023-06-09      6     Friday
# ..         ...    ...        ...
# 495 2023-08-25      8     Friday
# 496 2024-02-29      2   Thursday
# 497 2023-08-09      8  Wednesday
# 498 2023-03-09      3   Thursday
# 499 2023-07-16      7     Sunday
#
# [500 rows x 3 columns]

# %%
# View distribution of months
energy_data['month'].value_counts().sort_index()
# Out:
# month
# 1     64
# 2     65
# 3     60
# 4     47
# 5     27
# 6     44
# 7     28
# 8     40
# 9     29
# 10    26
# 11    29
# 12    41
# Name: count, dtype: int64

# %%
# Average energy usage per weekday
sns.barplot(x='weekday', y='daily_energy_kwh', data=energy_data, estimator='mean', color='steelblue', errorbar=None)
plt.title('Average Daily Energy Usage by Weekday')
plt.xlabel('Weekday')
plt.ylabel('Average kWh')
plt.xticks(rotation=45)
plt.show()

# %%
# Average energy usage per month
sns.barplot(x=energy_data['month'].astype(str), y=energy_data['daily_energy_kwh'], estimator='mean', 
            color='darkorange', errorbar=None, order=sorted(energy_data['month'].unique()))
plt.title('Average Daily Energy Usage by Month')
plt.xlabel('Month')
plt.ylabel('Average kWh')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **3. Lag Feature**

# %%
# Sort by "household_id" and "timestamp"
energy_data = energy_data.sort_values(['household_id','timestamp'])

# Create energy lagged variable
energy_data['kwh_lag1'] = (energy_data.groupby('timestamp')['daily_energy_kwh'].shift(1))

# %%
# Check the daily energy variable with its lagged version
energy_data[['household_id','timestamp','daily_energy_kwh','kwh_lag1']].sort_values(['timestamp','household_id'])
# Out:
#      household_id  timestamp  daily_energy_kwh  kwh_lag1
# 149           150 2023-01-03              1.58       NaN
# 342           343 2023-01-03              3.07      1.58
# 263           264 2023-01-04              7.80       NaN
# 312           313 2023-01-05              4.47       NaN
# 343           344 2023-01-06              8.16       NaN
# ..            ...        ...               ...       ...
# 0               1 2024-03-31              5.97       NaN
# 246           247 2024-03-31             13.67      5.97
# 291           292 2024-03-31              3.80     13.67
# 429           430 2024-03-31              2.77      3.80
# 240           241 2024-04-01              4.70       NaN
#
# [500 rows x 4 columns]

# %%
import itertools

# Create a synthetic dataset with 2 households and 10 days each
np.random.seed(42)
x = [101, 102]
y = pd.date_range(start='2023-01-01', periods=10, freq='D')

syn_data = (pd.DataFrame(itertools.product(x, y), 
                         columns = ['household_id', 'date']).sort_values(['household_id','date']).reset_index(drop=True))
syn_data['daily_energy_kwh'] = np.random.uniform(3, 10, len(syn_data)).round(1)
syn_data['kwh_lag1'] = (syn_data.groupby('household_id')['daily_energy_kwh'].shift(1))

syn_data
# Out:
#     household_id       date  daily_energy_kwh  kwh_lag1
# 0            101 2023-01-01               5.6       NaN
# 1            101 2023-01-02               9.7       5.6
# 2            101 2023-01-03               8.1       9.7
# 3            101 2023-01-04               7.2       8.1
# 4            101 2023-01-05               4.1       7.2
# 5            101 2023-01-06               4.1       4.1
# 6            101 2023-01-07               3.4       4.1
# 7            101 2023-01-08               9.1       3.4
# 8            101 2023-01-09               7.2       9.1
# 9            101 2023-01-10               8.0       7.2
# 10           102 2023-01-01               3.1       NaN
# 11           102 2023-01-02               9.8       3.1
# 12           102 2023-01-03               8.8       9.8
# 13           102 2023-01-04               4.5       8.8
# 14           102 2023-01-05               4.3       4.5
# 15           102 2023-01-06               4.3       4.3
# 16           102 2023-01-07               5.1       4.3
# 17           102 2023-01-08               6.7       5.1
# 18           102 2023-01-09               6.0       6.7
# 19           102 2023-01-10               5.0       6.0

# %%
# Create a Scatterplot to compare Current vs Lag-1 Usage
g = sns.FacetGrid(syn_data, col="household_id")

g.map_dataframe(sns.scatterplot, x="kwh_lag1", y="daily_energy_kwh")
g.map_dataframe(sns.regplot, x="kwh_lag1", y="daily_energy_kwh", ci=None, color="blue", scatter = False)

g.fig.suptitle("Current vs Lag-1 Energy Usage")
g.fig.subplots_adjust(top=0.8)

g.set_ylabels("Current kWh")
g.set_xlabels("")
g.fig.text(0.35, 0.05, "Lag-1 kWh (Previous Day)")
plt.show()

# %% [markdown]
# Binning Continuous Variables into Categories
#
# **Example 1: Binning Energy Usage into Equal-Frequency Categories**

# %%
# Breakpoints based on quantiles: 0%, 33%, 66%, and 100%
breaks = np.quantile(energy_data['daily_energy_kwh'], [0, 0.33, 0.66, 1])

# Assign labels to the bins
energy_data['kwh_bin'] = pd.cut(energy_data['daily_energy_kwh'], 
                                bins=breaks, labels = ["Low", "Medium", "High"], include_lowest=True)

# Observations per bin
energy_data['kwh_bin'].value_counts().sort_index()
# Out:
# kwh_bin
# Low       165
# Medium    165
# High      170
# Name: count, dtype: int64

# %% [markdown]
# **Example 2: Binning Environmental Awareness Score (Custom Bins)**

# %%
# Define breakpoints and labels to each bin
energy_data['awareness_disc'] = pd.cut(energy_data['green_awareness_score'], [0, 40, 70, 100], 
                                       labels=['Low', 'Medium', 'High'])

# Check the number of observations
energy_data['awareness_disc'].value_counts().sort_index()
# Out:
# awareness_disc
# Low       182
# Medium    205
# High      113
# Name: count, dtype: int64

# %% [markdown]
# **Example: Green Awareness Score Distribution by Energy Usage Level**

# %%
# Visualize Score Distribution by Energy Usage Level
sns.boxplot(energy_data, x='kwh_bin', y='green_awareness_score', boxprops = dict(edgecolor='darkgreen', facecolor='lightgreen'))
plt.title("Green Awareness Score by Energy Usage Level")
plt.xlabel("Energy Usage (Binned)")
plt.ylabel("Green Awareness Score")
sns.set_theme(style='whitegrid')
plt.show()
